# %% [markdown]
# Bai 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = np.array([[1,1],[3,2],[4,2],[5,4]])
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

print("Tam của nhom 1  là:%s"%kmeans.cluster_centers_[0])
print("Tam của nhom 2  là:%s"%kmeans.cluster_centers_[1])

predict = kmeans.fit_predict(X)
print("Ket qua du doan: %s"%predict)
plt.scatter(X[:, 0], X[:, 1], c=predict)
plt.ylabel("X (weight index)")
plt.xlabel("Y (pH)")
plt.title("Hinh anh phan cum")
plt.show()
# Out:
# Tam của nhom 1  là:[4.         2.66666667]
# Tam của nhom 2  là:[1. 1.]
# Ket qua du doan: [1 0 0 0]

# %% [markdown]
# Bai 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = np.array([[1,1],[2,1],[4,2],[5,3],[5,4],[6,5]])
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

print("Tam của nhom 1  là:%s"%kmeans.cluster_centers_[0])
print("Tam của nhom 2  là:%s"%kmeans.cluster_centers_[1])

predict = kmeans.fit_predict(X)
print("Ket qua du doan: %s"%predict)
plt.ylabel("X")
plt.xlabel("Y")
plt.scatter(X[:, 0], X[:, 1], c=predict)
plt.title("Hinh anh phan cum")
plt.show()
# Out:
# Tam của nhom 1  là:[5.  3.5]
# Tam của nhom 2  là:[1.5 1. ]
# Ket qua du doan: [1 1 0 0 0 0]

# %% [markdown]
# Bai 3

# %%
a)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

data = pd.read_csv('./Diem.csv')
X= data.loc[:,:].values
kmeans = KMeans(n_clusters=3, random_state=0).fit(data)

print("Tam của nhom 1 là:%s"%kmeans.cluster_centers_[0])
print("Tam của nhom 2 là:%s"%kmeans.cluster_centers_[1])
print("Tam của nhom 3 là:%s"%kmeans.cluster_centers_[2])

predict = kmeans.fit_predict(X)
print("Ket qua du doan: %s"%predict)
# Out:
# Tam của nhom 1 là:[6.75 4.75 9.  ]
# Tam của nhom 2 là:[5.14285714 4.         4.        ]
# Tam của nhom 3 là:[6.66666667 9.         6.66666667]
# Ket qua du doan: [0 2 0 1 1 0 2 1 1 2 1 2 2 2 0 2 1 2 2 1]

# %% [markdown]
# b)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

data = pd.read_csv('./Diem.csv')
X= data.loc[:,:].values
pca = PCA(n_components=2).fit_transform(X)

kmeans = KMeans(n_clusters=3, random_state=0).fit(pca)

print("Tam của nhom 1 là:%s"%kmeans.cluster_centers_[0])
print("Tam của nhom 2 là:%s"%kmeans.cluster_centers_[1])

predict = kmeans.fit_predict(pca)
print("Ket qua du doan: %s"%predict)

plt.scatter(pca[:, 0], pca[:, 1], c=predict)
plt.title("Hinh anh phan cum")
plt.show()
# Out:
# Tam của nhom 1 là:[-1.35770637  4.11457102]
# Tam của nhom 2 là:[-2.28956571 -0.69685068]
# Ket qua du doan: [1 1 2 2 2 1 1 2 2 1 2 1 0 0 1 1 2 1 0 2]

# %% [markdown]
# Bai 4

# %% [markdown]
# a)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

data = pd.read_csv('./bank-data.csv')
X= data.loc[:,['sex']].values
sex= {'FEMALE':0,'MALE':1}
data['sex'] = data['sex'].map(sex)
region ={'INNER_CITY':0,'TOWN':1,'RURAL':2, 'SUBURBAN':3}
data['region'] = data['region'].map(region)
b ={'YES':1, 'NO':0}
data['car'] =data['car'].map(b)
data['save_act']=data['save_act'].map(b)
data['married']=data['married'].map(b)
data['current_act']=data['current_act'].map(b)
data['mortgage']=data['mortgage'].map(b)
data['pep']=data['pep'].map(b)
X= data.loc[:,['age','sex','region','income','married','children','car','save_act','current_act','mortgage','pep']].values
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)
for i in range(5):
  print("Tam cum %s la: %s"%(i+1,kmeans.cluster_centers_[i]))
# Out:
# Tam cum 1 la: [3.95714286e+01 5.09316770e-01 9.56521739e-01 2.18614248e+04
#  7.20496894e-01 9.62732919e-01 4.40993789e-01 5.71428571e-01
#  7.08074534e-01 3.85093168e-01 4.40993789e-01]
# Tam cum 2 la: [5.30108696e+01 5.54347826e-01 9.02173913e-01 4.02533370e+04
#  6.63043478e-01 1.02173913e+00 5.32608696e-01 8.26086957e-01
#  7.93478261e-01 3.15217391e-01 4.67391304e-01]
# Tam cum 3 la: [2.85641026e+01 5.25641026e-01 7.88461538e-01 1.32847098e+04
#  6.34615385e-01 9.87179487e-01 4.48717949e-01 6.28205128e-01
#  7.75641026e-01 3.14102564e-01 3.14102564e-01]
# Tam cum 4 la: [4.54960630e+01 4.25196850e-01 9.37007874e-01 3.00625843e+04
#  6.14173228e-01 1.01574803e+00 5.66929134e-01 6.61417323e-01
#  7.55905512e-01 3.77952756e-01 5.03937008e-01]
# Tam cum 5 la: [6.17968750e+01 4.84375000e-01 1.12500000e+00 5.31415531e+04
#  6.56250000e-01 1.17187500e+00 5.31250000e-01 1.00000000e+00
#  7.96875000e-01 3.28125000e-01 7.34375000e-01]

# %% [markdown]
# b)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
data = pd.read_csv('./bank-data.csv')
X= data.loc[:,['sex']].values
sex= {'FEMALE':0,'MALE':1}
data['sex'] = data['sex'].map(sex)
region ={'INNER_CITY':0,'TOWN':1,'RURAL':2, 'SUBURBAN':3}
data['region'] = data['region'].map(region)
b ={'YES':1, 'NO':0}
data['car'] =data['car'].map(b)
data['save_act']=data['save_act'].map(b)
data['married']=data['married'].map(b)
data['current_act']=data['current_act'].map(b)
data['mortgage']=data['mortgage'].map(b)
data['pep']=data['pep'].map(b)
X= data.loc[:,['age','sex','region','income','married','children','car','save_act','current_act','mortgage','pep']].values

pca = PCA(n_components=2).fit_transform(X)
kmeans = KMeans(n_clusters=5, random_state=0).fit(pca)
for i in range(5):
  print("Tam cum %s la: %s"%(i,kmeans.cluster_centers_[i]))

predict = kmeans.fit_predict(pca)
plt.scatter(pca[:, 0], pca[:, 1], c=predict)
plt.title("Hinh anh phan cum")
plt.show()
# Out:
# Tam cum 0 la: [-5.66260674e+03  1.94293013e+00]
# Tam cum 1 la: [ 1.27293102e+04 -9.92042112e-02]
# Tam cum 2 la: [-1.42393280e+04 -1.84518977e+00]
# Tam cum 3 la: [2.53855475e+03 9.64746452e-01]
# Tam cum 4 la: [ 2.56175292e+04 -2.16184622e+00]
